# %% [markdown]
# 1.Algunos campos, como belongs_to_collection, production_companies y otros (ver diccionario de datos) están anidados, esto es o bien tienen un diccionario o una lista como valores en cada fila, ¡deberán desanidarlos para poder y unirlos al dataset de nuevo hacer alguna de las consultas de la API! O bien buscar la manera de acceder a esos datos sin desanidarlos.
#
# 2.Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0.
#
# 3.Los valores nulos del campo release date deben eliminarse.
#
# 4.De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde extraerán el año de la fecha de estreno.
#
# 5.Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget, dividiendo estas dos últimas revenue / budget, cuando no hay datos disponibles para calcularlo, deberá tomar el valor 0.
#
# 6.Eliminar las columnas que no serán utilizadas, video,imdb_id,adult,original_title,poster_path y homepage.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import ast
import json

# %%
#creo el data frame 
dfmovies = pd.read_csv(r'C:\Users\flori\Desktop\DATA SCIENCE\LABS\Trabajos\Proyecto_Indiv_1_MLO_Henry\DATASETS\movies_dataset.csv',low_memory=False)

# %%
dfmovies.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# 0   1995-10-30  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7     5415.0
#
# [1 rows x 24 columns]

# %%
dfmovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
dfmovies.shape
# Out:
# (45466, 24)

# %% [markdown]
# PUNTO 6

# %%
###elimino las columnas que me solicita en el punto 6
columnas_a_eliminar = ['video','imdb_id','adult','original_title','poster_path','homepage']
dfmovies2 = dfmovies.drop(columns=columnas_a_eliminar)

# %%
#me fijo que valores nulos hay
dfmovies2.isnull()
# Out:
#        belongs_to_collection  budget  genres     id  original_language  \
# 0                      False   False   False  False              False
# 1                       True   False   False  False              False
# 2                      False   False   False  False              False
# 3                       True   False   False  False              False
# 4                      False   False   False  False              False
# ...                      ...     ...     ...    ...                ...
# 45461                   True   False   False  False              False
# 45462                   True   False   False  False              False
# 45463                   True   False   False  False              False
# 45464                   True   False   False  False              False
# 45465                   True   False   False  False              False
#
#        overview  popularity  production_companies  production_countries  \
# ...

# %%
##cuento nulos y porcentaje de nulos en el DF sin las columnas que elimino
nulos_movies = pd.DataFrame(dfmovies2.isnull().sum().sort_values(ascending = False))
nulos_movies["Porcentaje de nulos"] = round(nulos_movies/dfmovies2.shape[0]*100,2)
nulos_movies.rename(columns = {0:"Nro nulos"})
# Out:
#                        Nro nulos  Porcentaje de nulos
# belongs_to_collection      40972                90.12
# tagline                    25054                55.10
# overview                     954                 2.10
# runtime                      263                 0.58
# status                        87                 0.19
# release_date                  87                 0.19
# original_language             11                 0.02
# revenue                        6                 0.01
# spoken_languages               6                 0.01
# title                          6                 0.01
# vote_average                   6                 0.01
# vote_count                     6                 0.01
# popularity                     5                 0.01
# production_companies           3                 0.01
# production_countries           3                 0.01
# budget                         0                 0.00
# ...

# %%
dfmovies2['release_date'].isnull().value_counts() 
## si pongo solo isnul me dice que hay cero..pero cuando pongo value counts diferencia entre true y false
# Out:
# False    45379
# True        87
# Name: release_date, dtype: int64

# %% [markdown]
# PUNTO 3

# %%
###elimino nulos de release date PUNTO 3
dfmovies2.dropna(subset=['release_date'], inplace=True)

# %% [markdown]
# PUNTO 4 CAMBIO A DATETIME

# %%
## cambio a date time el release date

dfmovies2['release_date'] = pd.to_datetime(dfmovies2['release_date'], errors='coerce')

# %%
dfmovies2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45379 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45379 non-null  object
#  2   genres                 45379 non-null  object
#  3   id                     45379 non-null  object
#  4   original_language      45368 non-null  object
#  5   overview               44438 non-null  object
#  6   popularity             45377 non-null  object
#  7   production_companies   45379 non-null  object
#  8   production_countries   45379 non-null  object
#  9   release_date           45376 non-null  datetime64[ns]
#  10  revenue                45376 non-null  float64
#  11  runtime                45130 non-null  float64
#  12  spoken_languages       45376 non-null  object
#  13  status                 45296 non-null  object
# ...

# %%
###AHORA HAGO LA COLUMNA YEAR
dfmovies2['release_year'] = dfmovies2['release_date'].dt.year

# %%
dfmovies2.head(2)
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
#
#                                               genres    id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  8844                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# ...

# %% [markdown]
# PUNTO 2
# REEMPLAZO VALORES NULOS POR CERO DE REVENUE Y BUDGET

# %%
dfmovies2['REVENUE'] = dfmovies2['revenue'].fillna(0)

# %%
dfmovies2['BUDGET']= dfmovies2['budget'].fillna(0)

# %%
columnas_a_eliminar2 = ['revenue','budget']
dfmovies2 = dfmovies2.drop(columns=columnas_a_eliminar2)

# %%
dfmovies2.head(2)
# Out:
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
#
#                                               genres    id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  8844                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30     81.0
# ...

# %% [markdown]
# PUNTO 5 COLUMNA RETORNO DE INVERSION

# %%
dfmovies2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45379 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   genres                 45379 non-null  object
#  2   id                     45379 non-null  object
#  3   original_language      45368 non-null  object
#  4   overview               44438 non-null  object
#  5   popularity             45377 non-null  object
#  6   production_companies   45379 non-null  object
#  7   production_countries   45379 non-null  object
#  8   release_date           45376 non-null  datetime64[ns]
#  9   runtime                45130 non-null  float64
#  10  spoken_languages       45376 non-null  object
#  11  status                 45296 non-null  object
#  12  tagline                20398 non-null  object
#  13  title                  45376 non-null  object
# ...

# %%
dfmovies2['BUDGET'].unique()
# Out:
# array(['30000000', '65000000', '0', ..., '3417000', '25868826', '1254040'],
#       dtype=object)

# %%
####TENGO QUE TRANSFORMAR LA COLUMNA BUDGET EN FLOAT PARA PODER DIVIDIRLAS
##dfmovies2['BUDGET'] = dfmovies2['BUDGET'].astype(float)
##este me tira error porque hay un valor con letras

# %%
dfmovies2['BUDGET'] = pd.to_numeric(dfmovies2['BUDGET'], errors='coerce')

# %%
dfmovies2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45379 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   genres                 45379 non-null  object
#  2   id                     45379 non-null  object
#  3   original_language      45368 non-null  object
#  4   overview               44438 non-null  object
#  5   popularity             45377 non-null  object
#  6   production_companies   45379 non-null  object
#  7   production_countries   45379 non-null  object
#  8   release_date           45376 non-null  datetime64[ns]
#  9   runtime                45130 non-null  float64
#  10  spoken_languages       45376 non-null  object
#  11  status                 45296 non-null  object
#  12  tagline                20398 non-null  object
#  13  title                  45376 non-null  object
# ...

# %%
dfmovies2['return'] = dfmovies2['REVENUE']/dfmovies2['BUDGET']

# %%
dfmovies2.head(2)
# Out:
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
#
#                                               genres    id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  8844                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30     81.0
# ...

# %%
dfmovies2.dropna(subset=['belongs_to_collection'], inplace=True)
#no se si lo tengo q eliminar...

# %% [markdown]
# PUNTO 1 DESANIDAR BELONGS_TO_COLLECTION Y PRODUCTION COMPANY

# %%
#### LO VOY A HACER EN ARCHIVOS APARTE LO DE DESANIDAR

# %%
pd.set_option('display.max_colwidth', None)

# %%
dfbelong= dfmovies2[['belongs_to_collection']]
dfbelong.head()
# Out:
#                                                                                                                                               belongs_to_collection
# 0             {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 2       {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 4   {'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}
# 9               {'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}
# 12               {'id': 117693, 'name': 'Balto Collection', 'poster_path': '/w0ZgH6Lgxt2bQYnf1ss74UvYftm.jpg', 'backdrop_path': '/9VM5LiJV0bGb1st1KyHA3cVnO2G.jpg'}

# %%
#dfbelong.astype('string')

#dfbelong = dfbelong['belongs_to_collection'].str.split(pat =',',expand = True)

#dfbelong = dfbelong.rename(columns = {0:'id_belongs',1:'name_belongs',2:'poster_path_belongs',3:'backdrop_path_belongs'})

# %%
df_unnested = pd.json_normalize(dfbelong, sep='_')
df_unnested.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %% [markdown]
# ME FIJO SI PUEDO ELIMINAR ALGUNA COLUMNA MAS

# %%
dfmovies2.head(1)
# Out:
#                                                                                                                                    belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
#
#                                                                                              genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
#
#     id original_language  \
# 0  862                en
#
#                                                                                                                                                                                                                                                                                                           overview  \
# ...

# %%
###me fijo si me sirve la columna status

grouped = dfmovies2[['id','status']].groupby('status').count()
grouped.head()
# Out:
#                    id
# status
# In Production       4
# Planned             1
# Post Production     6
# Released         4466
# Rumored             9

# %%
# separo las que en teoria el status era rumor, y son peliculas que ya se estrenaron porque todas tiene  realesed year
dfproduction= dfmovies2[dfmovies2['status']=='Rumored']

# %%
dfproduction= dfmovies2[dfmovies2['status']=='Planned']
dfproduction.head(1)
##tiene release date
# Out:
#                                                                                                                                       belongs_to_collection  \
# 30402  {'id': 14890, 'name': 'Bad Boys Collection', 'poster_path': '/tSVbihfvVTCbcm0zXKA7L8R6Y9v.jpg', 'backdrop_path': '/yUvBiiC77UY6SyKhfFyLj7DNbfh.jpg'}
#
#                                                                                             genres  \
# 30402  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}]
#
#           id original_language  \
# 30402  38700                en
#
#                                                                                           overview  \
# 30402  The continuing adventures of Miami detectives Mike Lowrey and Marcus Burnett. Plot unknown.
#
#       popularity  \
# 30402   2.178546
#
# ...

# %%
dfproduction= dfmovies2[dfmovies2['status']=='Post Production']
##tmb tienen release date

# %%
dfproduction= dfmovies2[dfmovies2['status']=='In Production']
#tienen release date y ya salieron

# %%
## ahora me fijo si puedo eliminar tag line
dfmovies['tagline'].unique()
# Out:
# array([nan, 'Roll the dice and unleash the excitement!',
#        'Still Yelling. Still Fighting. Still Ready for Love.', ...,
#        'Do you know what happened 50 years before "The Blair Witch Project"?',
#        'Rising and falling between a man and woman',
#        'A deadly game of wits.'], dtype=object)

# %%
### elimino mas columnas que a mi me parece que estan de mas
columnas_a_eliminar2 = ['tagline','status','vote_average','vote_count', 'release_date']
dfmovies3 = dfmovies2.drop(columns=columnas_a_eliminar2)

# %%
dfmovies3.head()
# Out:
#                                                                                                                                               belongs_to_collection  \
# 0             {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 2       {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 4   {'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}
# 9               {'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}
# 12               {'id': 117693, 'name': 'Balto Collection', 'poster_path': '/w0ZgH6Lgxt2bQYnf1ss74UvYftm.jpg', 'backdrop_path': '/9VM5LiJV0bGb1st1KyHA3cVnO2G.jpg'}
# ...

# %%
dfmovies3.to_csv("Primer_DF.csv", index=False)
