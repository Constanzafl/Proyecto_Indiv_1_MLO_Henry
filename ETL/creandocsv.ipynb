# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import ast
import json

# %%
dfmovies3= pd.read_csv(r'C:\Users\flori\Desktop\DATA SCIENCE\LABS\Trabajos\Proyecto_Indiv_1_MLO_Henry\ETL\Primer_DF.csv')

# %%
dfmovies3.head()
# Out:
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 2  {'id': 96871, 'name': 'Father of the Bride Col...
# 3  {'id': 645, 'name': 'James Bond Collection', '...
# 4  {'id': 117693, 'name': 'Balto Collection', 'po...
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 2                     [{'id': 35, 'name': 'Comedy'}]  11862                en
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...    710                en
# 4  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  21032                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# ...

# %%
## genero nuevos archivos CSV de cada columna a desanidar para que sea mas ordenado

# %%
# Crear un nuevo DataFrame con las columnas deseadas
dfcollections = dfmovies3[["id", "belongs_to_collection"]]

# # Guardar el DataFrame en un archivo CSV
dfcollections.to_csv("Collections.csv", index=False)

# %%
# Crear un nuevo DataFrame con las columnas deseadas
dfgenre = dfmovies3[["id", "genres"]]

# # Guardar el DataFrame en un archivo CSV
dfgenre.to_csv("Genres.csv", index=False)

# %%
# Crear un nuevo DataFrame con las columnas deseadas
dfproduction = dfmovies3[["id", "production_companies", "production_countries"]]

# # Guardar el DataFrame en un archivo CSV
dfproduction.to_csv("Production.csv", index=False)

# %%
# Crear un nuevo DataFrame con las columnas deseadas
dflanguage = dfmovies3[["id", "original_language"]]

# # Guardar el DataFrame en un archivo CSV
dflanguage.to_csv("Language.csv", index=False)
