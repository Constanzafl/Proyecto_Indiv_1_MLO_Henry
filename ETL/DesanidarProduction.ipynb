# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import ast
import json

# %%
pd.set_option('display.max_colwidth', None)

# %%
dfproduction= pd.read_csv(r'C:\Users\flori\Desktop\DATA SCIENCE\LABS\Trabajos\Proyecto_Indiv_1_MLO_Henry\ETL\Production.csv')
dfproduction.head()
# Out:
#       id  \
# 0    862
# 1  15602
# 2  11862
# 3    710
# 4  21032
#
#                                                                                                           production_companies  \
# 0                                                                               [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1                                              [{'name': 'Warner Bros.', 'id': 6194}, {'name': 'Lancaster Gate', 'id': 19464}]
# 2                                 [{'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Touchstone Pictures', 'id': 9195}]
# 3                                              [{'name': 'United Artists', 'id': 60}, {'name': 'Eon Productions', 'id': 7576}]
# 4  [{'name': 'Universal Pictures', 'id': 33}, {'name': 'Amblin Entertainment', 'id': 56}, {'name': 'Amblimation', 'id': 4105}]
#
#                                                                                          production_countries
# 0                                                  [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1                                                  [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2                                                  [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 4                                                  [{'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
def convertir_columna_diccionarios_a_dataframe(df, columna):
    # Obtener la columna que contiene los diccionarios
    column_data = df[columna]

    # Convertir los diccionarios a listas de diccionarios
    lista_diccionarios = column_data.apply(lambda x: eval(x) if pd.notna(x) else [])

    # Filtrar y eliminar los valores booleanos
    lista_diccionarios = [d for sublist in lista_diccionarios if isinstance(sublist, list) for d in sublist]

    # Crear el DataFrame resultante y seleccionar las columnas deseadas
    df_estudio = pd.DataFrame(lista_diccionarios, columns=['id', 'name'])

    return df_estudio

# Aplicar la función al DataFrame y obtener el DataFrame resultante
df_estudio = convertir_columna_diccionarios_a_dataframe(dfproduction, 'production_companies')

# Mostrar las primeras filas del DataFrame resultante
df_estudio.head()
# Out:
#       id                     name
# 0      3  Pixar Animation Studios
# 1   6194             Warner Bros.
# 2  19464           Lancaster Gate
# 3   5842    Sandollar Productions
# 4   9195      Touchstone Pictures

# %%
df_estudio.to_csv('EstudiosFinal.csv', index=False)

# %%
def convertir_columna_diccionarios_a_dataframe(df, columna):
    # Obtener la columna que contiene los diccionarios
    column_data = df[columna]

    # Convertir los diccionarios a listas de diccionarios
    lista_diccionarios = column_data.apply(lambda x: eval(x) if pd.notna(x) else [])

    # Filtrar y eliminar los valores booleanos
    lista_diccionarios = [d for sublist in lista_diccionarios if isinstance(sublist, list) for d in sublist]

    # Crear el DataFrame resultante y seleccionar las columnas deseadas
    df_pais = pd.DataFrame(lista_diccionarios, columns=['iso_3166_1', 'name'])

    return df_resultado

# Aplicar la función al DataFrame y obtener el DataFrame resultante
df_pais = convertir_columna_diccionarios_a_dataframe(dfproduction, 'production_countries')

# Mostrar las primeras filas del DataFrame resultante
df_pais.head()
# Out:
#   iso_3166_1                      name
# 0         US  United States of America
# 1         US  United States of America
# 2         US  United States of America
# 3         GB            United Kingdom
# 4         US  United States of America

# %%
df_pais.to_csv('PaisFinal.csv', index=False)
