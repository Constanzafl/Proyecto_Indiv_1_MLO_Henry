# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import ast
import json

# %%
pd.set_option('display.max_colwidth', None)

# %%
dfgenres= pd.read_csv(r'C:\Users\flori\Desktop\DATA SCIENCE\LABS\Trabajos\Proyecto_Indiv_1_MLO_Henry\ETL\Genres.csv')
dfgenres.head()
# Out:
#       id  \
# 0    862
# 1  15602
# 2  11862
# 3    710
# 4  21032
#
#                                                                                                 genres
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 1                                     [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 2                                                                       [{'id': 35, 'name': 'Comedy'}]
# 3      [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]
# 4  [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}]

# %%
dfgenres.sort_values(by='id', ascending=False)
# Out:
#           id  \
# 1584    9992
# 4371    9990
# 3054   99861
# 2362   99770
# 3640   99760
# ...      ...
# 1039   10009
# 1536   10007
# 2203   10005
# 2867  100042
# 207    10003
#
#                                                                                                                                                                          genres
# 1584                                         [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}]
# 4371                                                   [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]
# 3054                                                                    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}]
# ...

# %%
dfgenres['genres'] = dfgenres['genres'].apply(ast.literal_eval)

# %%
df_exploded = dfgenres.explode('genres', ignore_index=True) 
df_exploded.head()
# Out:
#       id                            genres
# 0    862   {'id': 16, 'name': 'Animation'}
# 1    862      {'id': 35, 'name': 'Comedy'}
# 2    862   {'id': 10751, 'name': 'Family'}
# 3  15602  {'id': 10749, 'name': 'Romance'}
# 4  15602      {'id': 35, 'name': 'Comedy'}

# %%
df_exploded['name_genres'] = df_exploded['genres'].apply(lambda x: x.get('name', '') if isinstance(x, dict) else '')
df_exploded['id_genres'] = df_exploded['genres'].apply(lambda x: x.get('id', '') if isinstance(x, dict) else '')

# %%
df_exploded.head()
# Out:
#       id                            genres name_genres id_genres
# 0    862   {'id': 16, 'name': 'Animation'}   Animation        16
# 1    862      {'id': 35, 'name': 'Comedy'}      Comedy        35
# 2    862   {'id': 10751, 'name': 'Family'}      Family     10751
# 3  15602  {'id': 10749, 'name': 'Romance'}     Romance     10749
# 4  15602      {'id': 35, 'name': 'Comedy'}      Comedy        35

# %%
df_exploded.drop(columns='genres')
# Out:
#            id name_genres id_genres
# 0         862   Animation        16
# 1         862      Comedy        35
# 2         862      Family     10751
# 3       15602     Romance     10749
# 4       15602      Comedy        35
# ...       ...         ...       ...
# 11151   19307      Comedy        35
# 11152   21251      Comedy        35
# 11153  460135   Animation        16
# 11154  182030      Action        28
# 11155  182030     Foreign     10769
#
# [11156 rows x 3 columns]

# %%
grouped_df = df_exploded.groupby('id').agg({'name_genres': lambda x: "'" + "' '".join(x) + "'",
                                           'id_genres': lambda x: "'" + ','.join(map(str, x)) + "'"}).reset_index()

grouped_df
# Out:
#           id                                                  name_genres  \
# 0      10003  'Thriller' 'Action' 'Romance' 'Science Fiction' 'Adventure'
# 1     100042                                                     'Comedy'
# 2      10005                              'Action' 'Adventure' 'Thriller'
# 3      10007                                          'Horror' 'Thriller'
# 4      10009                             'Adventure' 'Animation' 'Family'
# ...      ...                                                          ...
# 4483   99760                                                      'Drama'
# 4484   99770                                'Family' 'Adventure' 'Comedy'
# 4485   99861                       'Action' 'Adventure' 'Science Fiction'
# 4486    9990                          'Action' 'Thriller' 'Crime' 'Drama'
# 4487    9992                   'Adventure' 'Fantasy' 'Animation' 'Family'
#
#                  id_genres
# 0     '53,28,10749,878,12'
# ...

# %%
grouped_df.sort_values(by='id', ascending=False)
# Out:
#           id                                                  name_genres  \
# 4487    9992                   'Adventure' 'Fantasy' 'Animation' 'Family'
# 4486    9990                          'Action' 'Thriller' 'Crime' 'Drama'
# 4485   99861                       'Action' 'Adventure' 'Science Fiction'
# 4484   99770                                'Family' 'Adventure' 'Comedy'
# 4483   99760                                                      'Drama'
# ...      ...                                                          ...
# 4      10009                             'Adventure' 'Animation' 'Family'
# 3      10007                                          'Horror' 'Thriller'
# 2      10005                              'Action' 'Adventure' 'Thriller'
# 1     100042                                                     'Comedy'
# 0      10003  'Thriller' 'Action' 'Romance' 'Science Fiction' 'Adventure'
#
#                  id_genres
# 4487      '12,14,16,10751'
# ...

# %%
grouped_df['id'].unique()
# Out:
# array(['10003', '100042', '10005', ..., '99861', '9990', '9992'],
#       dtype=object)

# %%
df_exploded['id'].unique()
# Out:
# array(['862', '15602', '11862', ..., '21251', '460135', '182030'],
#       dtype=object)

# %%
def desanidar_generos(genres):
    """
    Desanida los géneros contenidos en una lista de diccionarios.

    Args:
        genres (list): Lista de diccionarios que representan los géneros.

    Returns:
        tuple: Una tupla que contiene dos listas: genero_id y genero_nombre.

    """
    genero_id = []
    genero_nombre = []
    for genero in genres:
        genero_id.append(genero['id'])
        genero_nombre.append(genero['name'])
    return genero_id, genero_nombre

# Aplicar la función desanidar_generos a la columna 'genres'
generos_desanidados = dfgenres['genres'].apply(lambda x: desanidar_generos(eval(x)))

# Crear un nuevo DataFrame a partir de los géneros desanidados
dfgeneros = pd.DataFrame(generos_desanidados.tolist(), columns=['ID_Genero', 'Genero'])

# Explotar las columnas para que cada fila tenga un solo género
dfgeneros = dfgeneros.apply(pd.Series.explode)

# Reiniciar el índice del DataFrame
dfgeneros = dfgeneros.reset_index(drop=True)

# Mostrar las primeras filas del nuevo DataFrame
dfgeneros.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 20
#      17     return genero_id, genero_nombre
#      19 # Aplicar la función desanidar_generos a la columna 'genres'
# ---> 20 generos_desanidados = dfgenres['genres'].apply(lambda x: desanidar_generos(eval(x)))
#      22 # Crear un nuevo DataFrame a partir de los géneros desanidados
#      23 dfgeneros = pd.DataFrame(generos_desanidados.tolist(), columns=['ID_Genero', 'Genero'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# ...

# %%
dfgeneros.head()

# %%
genera_Data = pd.concat([dfgenres, dfgeneros[['ID_Genero', 'Genero']]], axis=1) 
genera_Data.head()
# Out:
#       id  \
# 0    862
# 1  15602
# 2  11862
# 3    710
# 4  21032
#
#                                                                                                 genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 1                                     [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 2                                                                       [{'id': 35, 'name': 'Comedy'}]
# 3      [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]
# 4  [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}]
#
#   ID_Genero     Genero
# 0        16  Animation
# 1        35     Comedy
# 2     10751     Family
# 3     10749    Romance
# 4        35     Comedy

# %%
genera_Data.drop(columns='genres')
# Out:
#           id ID_Genero     Genero
# 0        862        16  Animation
# 1      15602        35     Comedy
# 2      11862     10751     Family
# 3        710     10749    Romance
# 4      21032        35     Comedy
# ...      ...       ...        ...
# 11151    NaN        35     Comedy
# 11152    NaN        35     Comedy
# 11153    NaN        16  Animation
# 11154    NaN        28     Action
# 11155    NaN     10769    Foreign
#
# [11156 rows x 3 columns]

# %%
len(genera_Data['Genero'].unique())
# Out:
# 33

# %%
genera_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11156 entries, 0 to 11155
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         4491 non-null   object
#  1   genres     4491 non-null   object
#  2   ID_Genero  11089 non-null  object
#  3   Genero     11089 non-null  object
# dtypes: object(4)
# memory usage: 348.8+ KB

# %%
dfgeneros.shape
# Out:
# (11156, 2)

# %%
dfgeneros.to_csv('GenerosFinal.csv', index=False)

# %%
dfgenres2= pd.read_csv(r'C:\Users\flori\Desktop\DATA SCIENCE\LABS\Trabajos\Proyecto_Indiv_1_MLO_Henry\DATASETS\movies_test.csv')

# %%
dfgenres2['genres'] = dfgenres2['genres'].apply(ast.literal_eval)

# %%
df_exploded2 = dfgenres2.explode('genres', ignore_index=True)

# %%
df_exploded2['name_genres'] = df_exploded2['genres'].apply(lambda x: x.get('name', '') if isinstance(x, dict) else '')
df_exploded2['id_genres'] = df_exploded2['genres'].apply(lambda x: x.get('id', '') if isinstance(x, dict) else '')

# %%
df_exploded2.head(1)
# Out:
#    adult  \
# 0  False
#
#                                                                                                                                    belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
#
#      budget                           genres  \
# 0  30000000  {'id': 16, 'name': 'Animation'}
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title  \
# 0      Toy Story
#
#                                                                                                                                                                                                                                                                                                           overview  \
# ...

# %%
dfprueba = df_exploded2[['id','id_genres','name_genres']]
dfprueba
# Out:
#        id  id_genres name_genres
# 0     862         16   Animation
# 1     862         35      Comedy
# 2     862      10751      Family
# 3    8844         12   Adventure
# 4    8844         14     Fantasy
# 5    8844      10751      Family
# 6   15602      10749     Romance
# 7   15602         35      Comedy
# 8   31357         35      Comedy
# 9   31357         18       Drama
# 10  31357      10749     Romance
# 11  11862         35      Comedy

# %%
grouped_df2 = df_exploded2.groupby('id').agg({'name_genres': lambda x: "'" + "' '".join(x) + "'",
                                           'id_genres': lambda x: "'" + ','.join(map(str, x)) + "'"}).reset_index()

grouped_df2
# Out:
#       id                     name_genres      id_genres
# 0    862   'Animation' 'Comedy' 'Family'  '16,35,10751'
# 1   8844  'Adventure' 'Fantasy' 'Family'  '12,14,10751'
# 2  11862                        'Comedy'           '35'
# 3  15602              'Romance' 'Comedy'     '10749,35'
# 4  31357      'Comedy' 'Drama' 'Romance'  '35,18,10749'

# %%
grouped_df2.sort_values(by='id', ascending=False)
# Out:
#       id                     name_genres      id_genres
# 4  31357      'Comedy' 'Drama' 'Romance'  '35,18,10749'
# 3  15602              'Romance' 'Comedy'     '10749,35'
# 2  11862                        'Comedy'           '35'
# 1   8844  'Adventure' 'Fantasy' 'Family'  '12,14,10751'
# 0    862   'Animation' 'Comedy' 'Family'  '16,35,10751'
