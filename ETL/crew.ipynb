# %%
import pandas as pd
import ast
import numpy as np
df=pd.read_csv(r'C:\Users\flori\Desktop\DATA SCIENCE\LABS\credits\credits.csv')

# %%
data=df["crew"]
data=data.str.replace("[ ]"," \'credit_id\': null ,\'department\': null,\'gender\': null, \'id\': null,\'job\': null,\'name\': null, \'profile_path\': null")
# Out:
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\1202167303.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data=data.str.replace("[ ]"," \'credit_id\': null ,\'department\': null,\'gender\': null, \'id\': null,\'job\': null,\'name\': null, \'profile_path\': null")

# %%
data=data.str.replace("{","")
data=data.str.replace("[","")
data=data.str.replace("]","")
data=data.str.replace("\'credit_id\':","")
data=data.str.replace("\'department\':","")
data=data.str.replace("\'gender\':","")
data=data.str.replace(" \'id\':","")
#data=data.str.replace("\'job\': ","")
data=data.str.replace("\'name\':","")
data=data.str.replace(" \'profile_path\': ","")
# Out:
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\989913031.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data=data.str.replace("{","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\989913031.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data=data.str.replace("[","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\989913031.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data=data.str.replace("]","")

# %%
def Separar(lista):
    dat=lista.split("},")
    dat=pd.DataFrame(dat)
    dat=dat
   
    return dat

# %%
def Separa(lista):
    dat=lista.split(",")
    dat=pd.DataFrame(dat)
    dat=dat.T
   
    return dat

# %%
def Director(x):
    b=Separar(x)
    b=b[0]
    b=b.str.replace("}","")

    crew= pd.concat(list(map(lambda i: Separa(i), b)))

    crew= crew[[4,5]]
    crew.reset_index(inplace=True)
    crew=crew.rename(columns={4:"job"})
    crew=crew.drop(["index"],axis=1)
    crew["job"]=crew["job"].astype(str)
    crew.head()

    resultado=crew.loc[crew["job"]==" 'job': 'Director'"]
    resultado=resultado[5]
    resultado=pd.DataFrame(resultado)
    resultado=resultado.T
    resultado["Nombre"] =resultado.apply(lambda x: ''.join(x.astype(str)), axis=1)
    resultado=resultado["Nombre"]
    resultado=pd.DataFrame(resultado)
    
    return resultado

# %%
h=data[17]
h=Director(h)
h
# Out:
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
#   Nombre
# 5

# %%
Direc=pd.DataFrame()
Direc=pd.concat(list(map(lambda i: Director(i), data)))
Direc
# Out:
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# C:\Users\flori\AppData\Local\Temp\ipykernel_18980\3332315918.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   b=b.str.replace("}","")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 Direc=pd.DataFrame()
# ----> 2 Direc=pd.concat(list(map(lambda i: Director(i), data)))
#       3 Direc
#
# Cell In[10], line 2, in <lambda>(i)
#       1 Direc=pd.DataFrame()
# ----> 2 Direc=pd.concat(list(map(lambda i: Director(i), data)))
#       3 Direc
#
# Cell In[8], line 8, in Director(x)
#       4 b=b.str.replace("}","")
#       6 crew= pd.concat(list(map(lambda i: Separa(i), b)))
# ----> 8 crew= crew[[4,5]]
#       9 crew.reset_index(inplace=True)
#      10 crew=crew.rename(columns={4:"job"})
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([4, 5], dtype='int64')] are in the [columns]"

# %%
Direc.reset_index()
# Out:
#        index                Nombre
# 0          5       'John Lasseter'
# 1          5        'Joe Johnston'
# 2          5       'Howard Deutch'
# 3          5     'Forest Whitaker'
# 4          5       'Charles Shyer'
# ...      ...                   ...
# 45471      5    'Hamid Nematollah'
# 45472      5            'Lav Diaz'
# 45473      5      'Mark L. Lester'
# 45474      5    'Yakov Protazanov'
# 45475      5       'Daisy Asquith'
#
# [45476 rows x 2 columns]

# %%
Direc=Direc["Nombre"]

# %%
# Out:
# 5         'John Lasseter'
# 5          'Joe Johnston'
# 5         'Howard Deutch'
# 5       'Forest Whitaker'
# 5         'Charles Shyer'
#              ...
# 5      'Hamid Nematollah'
# 5              'Lav Diaz'
# 5        'Mark L. Lester'
# 5      'Yakov Protazanov'
# 5         'Daisy Asquith'
# Name: Nombre, Length: 45476, dtype: object
